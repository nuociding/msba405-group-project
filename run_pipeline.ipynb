# %% [markdown]
# # Whole Foods Location Pipeline Execution Demo
#
# This notebook demonstrates the execution of the end-to-end data pipeline.

# %%
# !pip install papermill

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !bash /content/drive/MyDrive/msba405-group-project/run_pipeline.sh
# Out:
# ...
# Starting Whole Foods Location Scoring Pipeline
# ...
#
# [Stage 1/3] Running tract-level data processing pipeline
# Objective: Clean raw datasets and generate tract-level feature tables
# Input Notebook:  /content/drive/MyDrive/msba405-group-project/notebooks/data_processing.ipynb
# Output Notebook: /content/drive/MyDrive/msba405-group-project/pipeline_outputs/data_processing_executed.ipynb
# Executing:   0% 0/81 [00:00<?, ?cell/s]Executing notebook with kernel: python3
# Executing:  26% 21/81 [02:28<01:45,  1.76s/cell]unhandled iopub msg: colab_request
# unhandled iopub msg: colab_request
# unhandled iopub msg: colab_request
# Executing: 100% 81/81 [02:54<00:00,  2.15s/cell]
#
# [Stage 2/3] Running Spark similarity scoring model
# Objective: Merge tract features, compute similarity scores, and rank candidate locations
# Input Notebook:  /content/drive/MyDrive/msba405-group-project/notebooks/whole_foods_location_similarity_model.ipynb
# ...
